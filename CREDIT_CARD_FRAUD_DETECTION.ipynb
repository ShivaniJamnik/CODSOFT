# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# loading the dataset to a Pandas DataFrame
credit_card_data = pd.read_csv('/content/fraudTest.csv')

# %%
# loading the dataset to a Pandas DataFrame
 # loading the dataset to a Pandas DataFrame
credit_card_data= pd.read_csv('/content/fraudTrain.csv')

# %%
# first 5 rows of the dataset
credit_card_data.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2020-06-21 12:14:25  2291163933867244
# 1           1   2020-06-21 12:14:33  3573030041201292
# 2           2   2020-06-21 12:14:53  3598215285024754
# 3           3   2020-06-21 12:15:15  3591919803438423
# 4           4   2020-06-21 12:15:17  3526826139003047
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street  ...      lat      long  \
# 0   Elliott      M            351 Darlene Green  ...  33.9659  -80.9355
# ...

# %%
credit_card_data.tail()
# Out:
#         Unnamed: 0 trans_date_trans_time               cc_num  \
# 143682      143682   2020-08-10 14:32:10       36078114201167
# 143683      143683   2020-08-10 14:32:20     3582754887089201
# 143684      143684   2020-08-10 14:32:23       30242921189660
# 143685      143685   2020-08-10 14:32:41     3540862542587229
# 143686      143686   2020-08-10 14:32:54  4560004149983868183
#
#                        merchant        category    amt        first      last  \
# 143682  fraud_Reichert-Weissnat          travel   6.03  Christopher      Horn
# 143683        fraud_Waelchi Inc       kids_pets  57.27     Terrance  Mckinney
# 143684    fraud_Lubowitz-Walter       kids_pets  20.87       Dalton     Jones
# 143685        fraud_Friesen Ltd  health_fitness  85.02        Nancy     Roach
# 143686                    fraud             NaN    NaN          NaN       NaN
#
#        gender                             street  ...      lat      long  \
# ...

# %%
# dataset informations
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143687 entries, 0 to 143686
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             143687 non-null  int64
#  1   trans_date_trans_time  143687 non-null  object
#  2   cc_num                 143687 non-null  int64
#  3   merchant               143687 non-null  object
#  4   category               143686 non-null  object
#  5   amt                    143686 non-null  float64
#  6   first                  143686 non-null  object
#  7   last                   143686 non-null  object
#  8   gender                 143686 non-null  object
#  9   street                 143686 non-null  object
#  10  city                   143686 non-null  object
#  11  state                  143686 non-null  object
#  12  zip                    143686 non-null  float64
#  13  lat                    143686 non-null  float64
# ...

# %%
# checking the number of missing values in each column
credit_card_data.isnull().sum()
# Out:
# Unnamed: 0               0
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 1
# amt                      1
# first                    1
# last                     1
# gender                   1
# street                   1
# city                     1
# state                    1
# zip                      1
# lat                      1
# long                     1
# city_pop                 1
# job                      1
# dob                      1
# trans_num                1
# unix_time                1
# merch_lat                1
# merch_long               1
# is_fraud                 1
# dtype: int64

# %%
# distribution of legit transactions & fraudulent transactions
credit_card_data['is_fraud'].value_counts()
# Out:
# is_fraud
# 0.0    143059
# 1.0       627
# Name: count, dtype: int64

# %%
# separating the data for analysis
legit = credit_card_data[credit_card_data.is_fraud == 0]
fraud = credit_card_data[credit_card_data.is_fraud == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (143059, 23)
# (627, 23)

# %%
# statistical measures of the data
legit.city_pop.describe()
# Out:
# count    1.430590e+05
# mean     8.840450e+04
# std      3.005882e+05
# min      2.300000e+01
# 25%      7.410000e+02
# 50%      2.408000e+03
# 75%      2.032800e+04
# max      2.906700e+06
# Name: city_pop, dtype: float64

# %%
fraud.city_pop.describe()
# Out:
# count       627.000000
# mean      54082.503987
# std      157086.506795
# min          23.000000
# 25%        1606.000000
# 50%        4090.000000
# 75%       14742.000000
# max      841711.000000
# Name: city_pop, dtype: float64

# %%
numeric_credit_card_data = credit_card_data1.select_dtypes(include=np.number)
numeric_credit_card_data.groupby('is_fraud').mean()
# Out:
#             Unnamed: 0        cc_num         amt           zip        lat  \
# is_fraud
# 0.0       73831.235402  4.167122e+17   67.475057  48776.174644  38.532798
# 1.0       71230.103192  3.878578e+17  513.937506  47801.926503  39.100763
#
#                long       city_pop     unix_time  merch_lat  merch_long
# is_fraud
# 0.0      -90.197666   89872.617827  1.329030e+09  38.534329  -90.198199
# 1.0      -90.023428  110483.288790  1.328909e+09  39.093512  -90.028748

# %%
legit_sample = legit.sample(n=492)

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#         Unnamed: 0 trans_date_trans_time            cc_num  \
# 30606        30606   2020-07-01 08:59:53    36890292963032
# 31306        31306   2020-07-01 17:46:26  6506116513503136
# 134298      134298   2020-08-07 10:50:37   343668971234893
# 116181      116181   2020-08-01 03:55:25  6534628260579800
# 104927      104927   2020-07-27 19:29:03  3533012926413100
#
#                                    merchant       category    amt      first  \
# 30606     fraud_Raynor, Reinger and Hagenes  gas_transport  36.98   Kimberly
# 31306   fraud_Bernhard, Grant and Langworth   shopping_pos   2.22   Kimberly
# 134298               fraud_Hermann and Sons   shopping_pos   3.71      Sally
# 116181                      fraud_Kunze Inc    grocery_pos  90.17  Christine
# 104927                 fraud_Williamson LLC       misc_pos   1.04      Megan
#
#            last gender                          street  ...      lat     long  \
# ...

# %%
new_dataset.tail()
# Out:
#         Unnamed: 0 trans_date_trans_time           cc_num  \
# 141633      141633   2020-08-09 23:37:38  343819048608995
# 141703      141703   2020-08-10 00:11:25   30238755902988
# 141890      141890   2020-08-10 01:37:41   30238755902988
# 142143      142143   2020-08-10 03:41:31   30238755902988
# 142661      142661   2020-08-10 07:38:57   30238755902988
#
#                                   merchant       category     amt     first  \
# 141633                fraud_Kutch and Sons    grocery_pos  280.74    Shelby
# 141703  fraud_Reichert, Shanahan and Hayes   shopping_net  935.97  Danielle
# 141890    fraud_Swaniawski, Lowe and Robel   shopping_pos  862.53  Danielle
# 142143               fraud_Cummerata-Jones  gas_transport   11.17  Danielle
# 142661                  fraud_Zemlak Group       misc_net  876.32  Danielle
#
#           last gender                      street  ...      lat     long  \
# 141633  Cannon      F   1535 Ryan Burgs Suite 919  ...  41.5855 -93.6719
# ...

# %%
new_dataset['is_fraud'].value_counts()
# Out:
# is_fraud
# 1.0    627
# 0.0    492
# Name: count, dtype: int64

# %%
numeric_new_dataset = new_dataset.select_dtypes(include=np.number)
numeric_new_dataset.groupby('is_fraud').mean()
# Out:
#             Unnamed: 0        cc_num         amt           zip        lat  \
# is_fraud
# 0.0       71581.378049  3.257835e+17   65.178760  49761.101626  38.681074
# 1.0       77459.992026  7.205190e+17  493.546061  47246.984051  38.772832
#
#                long      city_pop     unix_time  merch_lat  merch_long
# is_fraud
# 0.0      -90.839311  87807.676829  1.373951e+09   38.67226  -90.814363
# 1.0      -90.798556  54082.503987  1.374130e+09   38.75460  -90.810458

# %%
X = new_dataset.drop(columns='is_fraud', axis=1)
Y = new_dataset['is_fraud']

# %%
print(X)
# Out:
#         Unnamed: 0 trans_date_trans_time            cc_num  \
# 30606        30606   2020-07-01 08:59:53    36890292963032
# 31306        31306   2020-07-01 17:46:26  6506116513503136
# 134298      134298   2020-08-07 10:50:37   343668971234893
# 116181      116181   2020-08-01 03:55:25  6534628260579800
# 104927      104927   2020-07-27 19:29:03  3533012926413100
# ...            ...                   ...               ...
# 141633      141633   2020-08-09 23:37:38   343819048608995
# 141703      141703   2020-08-10 00:11:25    30238755902988
# 141890      141890   2020-08-10 01:37:41    30238755902988
# 142143      142143   2020-08-10 03:41:31    30238755902988
# 142661      142661   2020-08-10 07:38:57    30238755902988
#
#                                    merchant       category     amt      first  \
# 30606     fraud_Raynor, Reinger and Hagenes  gas_transport   36.98   Kimberly
# 31306   fraud_Bernhard, Grant and Langworth   shopping_pos    2.22   Kimberly
# ...

# %%
print(Y)
# Out:
# 30606     0.0
# 31306     0.0
# 134298    0.0
# 116181    0.0
# 104927    0.0
#          ...
# 141633    1.0
# 141703    1.0
# 141890    1.0
# 142143    1.0
# 142661    1.0
# Name: is_fraud, Length: 1119, dtype: float64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (1119, 22) (895, 22) (224, 22)

# %%
string_columns = new_dataset.select_dtypes(include='object').columns.tolist()
new_dataset = new_dataset.drop(columns=string_columns)

# %%
print(new_dataset.dtypes)

X = new_dataset.drop(columns='is_fraud', axis=1)
Y = new_dataset['is_fraud']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

print(X.shape, X_train.shape, X_test.shape)

model = LogisticRegression(max_iter=500)
model.fit(X_train, Y_train)
# Out:
# Unnamed: 0      int64
# cc_num          int64
# amt           float64
# zip           float64
# lat           float64
# long          float64
# city_pop      float64
# unix_time     float64
# merch_lat     float64
# merch_long    float64
# is_fraud      float64
# dtype: object
# (1119, 10) (895, 10) (224, 10)
# LogisticRegression(max_iter=500)

# %%
model.fit(X_train, Y_train)
# Out:
# LogisticRegression(max_iter=500)

# %%
# accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data : ',training_data_accuracy)
# Out:
# Accuracy on Training data :  0.5597765363128492

# %%
# accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score on Test Data : ', test_data_accuracy)
# Out:
# Accuracy score on Test Data :  0.5625
